# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime
# Import the requests library.
import requests

import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 727

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gornozavodsk
# Processing Record 2 of Set 1 | havelock
# Processing Record 3 of Set 1 | kodiak
# Processing Record 4 of Set 1 | najran
# Processing Record 5 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 1 | acapulco
# Processing Record 7 of Set 1 | arman
# Processing Record 8 of Set 1 | eyl
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | dikson
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | talnakh
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | luderitz
# Processing Record 20 of Set 1 | kaitangata
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | bayan
# Processing Record 25 of Set 1 | timmins
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | ha tinh
# Processing Record 28 of Set 1 | bilibino
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 1 | kostomuksha
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | svetlaya
# Processing Record 35 of Set 1 | ariquemes
# Processing Record 36 of Set 1 | codrington
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | ponta do sol
# Processing Record 39 of Set 1 | kawalu
# Processing Record 40 of Set 1 | avera
# Processing Record 41 of Set 1 | poltavka
# Processing Record 42 of Set 1 | inhambane
# Processing Record 43 of Set 1 | saskylakh
# Processing Record 44 of Set 1 | san cristobal
# Processing Record 45 of Set 1 | lezajsk
# Processing Record 46 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 1 | bilma
# Processing Record 48 of Set 1 | kirakira
# Processing Record 49 of Set 1 | faanui
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | wieliczka
# Processing Record 2 of Set 2 | manacapuru
# Processing Record 3 of Set 2 | buala
# Processing Record 4 of Set 2 | cidreira
# Processing Record 5 of Set 2 | inirida
# Processing Record 6 of Set 2 | chuy
# Processing Record 7 of Set 2 | puerto penasco
# Processing Record 8 of Set 2 | mar del plata
# Processing Record 9 of Set 2 | saint george
# Processing Record 10 of Set 2 | laguna
# Processing Record 11 of Set 2 | provideniya
# Processing Record 12 of Set 2 | araouane
# Processing Record 13 of Set 2 | margate
# Processing Record 14 of Set 2 | albany
# Processing Record 15 of Set 2 | hofn
# Processing Record 16 of Set 2 | mahebourg
# Processing Record 17 of Set 2 | richards bay
# Processing Record 18 of Set 2 | tuktoyaktuk
# Processing Record 19 of Set 2 | leibnitz
# Processing Record 20 of Set 2 | ler
# Processing Record 21 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 2 | bikaner
# Processing Record 23 of Set 2 | olafsvik
# Processing Record 24 of Set 2 | samarai
# Processing Record 25 of Set 2 | dharmadam
# Processing Record 26 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 2 | chokurdakh
# Processing Record 28 of Set 2 | jasper
# Processing Record 29 of Set 2 | butaritari
# Processing Record 30 of Set 2 | launceston
# Processing Record 31 of Set 2 | clarksburg
# Processing Record 32 of Set 2 | forest
# Processing Record 33 of Set 2 | vaini
# Processing Record 34 of Set 2 | bathsheba
# Processing Record 35 of Set 2 | qaanaaq
# Processing Record 36 of Set 2 | reconquista
# Processing Record 37 of Set 2 | jalu
# Processing Record 38 of Set 2 | gurskoye
# City not found. Skipping...
# Processing Record 39 of Set 2 | port blair
# Processing Record 40 of Set 2 | saint-philippe
# Processing Record 41 of Set 2 | grindavik
# Processing Record 42 of Set 2 | alice springs
# Processing Record 43 of Set 2 | castro
# Processing Record 44 of Set 2 | torbay
# Processing Record 45 of Set 2 | yeppoon
# Processing Record 46 of Set 2 | silver city
# Processing Record 47 of Set 2 | kieta
# Processing Record 48 of Set 2 | te anau
# Processing Record 49 of Set 2 | lircay
# Processing Record 50 of Set 2 | bethel
# Processing Record 1 of Set 3 | ribeira grande
# Processing Record 2 of Set 3 | cabo san lucas
# Processing Record 3 of Set 3 | esperance
# Processing Record 4 of Set 3 | miri
# Processing Record 5 of Set 3 | kodinsk
# Processing Record 6 of Set 3 | olinda
# Processing Record 7 of Set 3 | parana
# Processing Record 8 of Set 3 | longyearbyen
# Processing Record 9 of Set 3 | usinsk
# Processing Record 10 of Set 3 | new norfolk
# Processing Record 11 of Set 3 | pangody
# Processing Record 12 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 3 | pop
# Processing Record 15 of Set 3 | sisimiut
# Processing Record 16 of Set 3 | pontianak
# Processing Record 17 of Set 3 | kapaa
# Processing Record 18 of Set 3 | ennis
# Processing Record 19 of Set 3 | sao filipe
# Processing Record 20 of Set 3 | jibuti
# Processing Record 21 of Set 3 | naze
# Processing Record 22 of Set 3 | irbeyskoye
# Processing Record 23 of Set 3 | kifri
# Processing Record 24 of Set 3 | yellowknife
# Processing Record 25 of Set 3 | sinnamary
# Processing Record 26 of Set 3 | nanortalik
# Processing Record 27 of Set 3 | plainview
# Processing Record 28 of Set 3 | ciudad bolivar
# Processing Record 29 of Set 3 | mount gambier
# Processing Record 30 of Set 3 | kimbe
# Processing Record 31 of Set 3 | high rock
# Processing Record 32 of Set 3 | dunedin
# Processing Record 33 of Set 3 | praxedis guerrero
# Processing Record 34 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 3 | hithadhoo
# Processing Record 36 of Set 3 | ahumada
# City not found. Skipping...
# Processing Record 37 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 3 | east london
# Processing Record 39 of Set 3 | carmo do rio claro
# Processing Record 40 of Set 3 | pangnirtung
# Processing Record 41 of Set 3 | tilichiki
# Processing Record 42 of Set 3 | klaksvik
# Processing Record 43 of Set 3 | hasaki
# Processing Record 44 of Set 3 | ilulissat
# Processing Record 45 of Set 3 | nanning
# Processing Record 46 of Set 3 | shuya
# Processing Record 47 of Set 3 | oruro
# Processing Record 48 of Set 3 | georgetown
# Processing Record 49 of Set 3 | victor harbor
# Processing Record 50 of Set 3 | sitka
# Processing Record 1 of Set 4 | cherskiy
# Processing Record 2 of Set 4 | kandrian
# Processing Record 3 of Set 4 | biltine
# Processing Record 4 of Set 4 | osakarovka
# Processing Record 5 of Set 4 | touros
# Processing Record 6 of Set 4 | nchelenge
# Processing Record 7 of Set 4 | coquimbo
# Processing Record 8 of Set 4 | khani
# Processing Record 9 of Set 4 | mokhotlong
# Processing Record 10 of Set 4 | airai
# Processing Record 11 of Set 4 | husavik
# Processing Record 12 of Set 4 | fukue
# Processing Record 13 of Set 4 | gerede
# Processing Record 14 of Set 4 | charcas
# Processing Record 15 of Set 4 | pacific grove
# Processing Record 16 of Set 4 | cajabamba
# Processing Record 17 of Set 4 | lima
# Processing Record 18 of Set 4 | fuerte
# Processing Record 19 of Set 4 | clyde river
# Processing Record 20 of Set 4 | tsentralnyy
# City not found. Skipping...
# Processing Record 21 of Set 4 | fort dodge
# Processing Record 22 of Set 4 | port hardy
# Processing Record 23 of Set 4 | oksfjord
# Processing Record 24 of Set 4 | tiksi
# Processing Record 25 of Set 4 | bichura
# Processing Record 26 of Set 4 | boa vista
# Processing Record 27 of Set 4 | bonavista
# Processing Record 28 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 29 of Set 4 | flinders
# Processing Record 30 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 4 | arraial do cabo
# Processing Record 33 of Set 4 | tura
# Processing Record 34 of Set 4 | katsuura
# Processing Record 35 of Set 4 | yulara
# Processing Record 36 of Set 4 | lapeer
# Processing Record 37 of Set 4 | vilyuysk
# Processing Record 38 of Set 4 | kyabe
# Processing Record 39 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 4 | mwinilunga
# Processing Record 41 of Set 4 | la libertad
# Processing Record 42 of Set 4 | fortuna
# Processing Record 43 of Set 4 | atar
# Processing Record 44 of Set 4 | calabozo
# Processing Record 45 of Set 4 | kruisfontein
# Processing Record 46 of Set 4 | puerto quijarro
# Processing Record 47 of Set 4 | komsomolskiy
# Processing Record 48 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 4 | polis
# Processing Record 50 of Set 4 | brae
# Processing Record 1 of Set 5 | ossora
# Processing Record 2 of Set 5 | xingcheng
# Processing Record 3 of Set 5 | moose factory
# Processing Record 4 of Set 5 | kuito
# Processing Record 5 of Set 5 | paamiut
# Processing Record 6 of Set 5 | sillod
# Processing Record 7 of Set 5 | irbil
# Processing Record 8 of Set 5 | sao miguel do araguaia
# Processing Record 9 of Set 5 | banting
# Processing Record 10 of Set 5 | paso de los toros
# Processing Record 11 of Set 5 | lorengau
# Processing Record 12 of Set 5 | ucluelet
# Processing Record 13 of Set 5 | bambous virieux
# Processing Record 14 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 5 | antofagasta
# Processing Record 16 of Set 5 | guerrero negro
# Processing Record 17 of Set 5 | doha
# Processing Record 18 of Set 5 | bengkulu
# Processing Record 19 of Set 5 | victoria
# Processing Record 20 of Set 5 | ransang
# Processing Record 21 of Set 5 | alekseyevka
# Processing Record 22 of Set 5 | venancio aires
# Processing Record 23 of Set 5 | mareeba
# Processing Record 24 of Set 5 | etchojoa
# Processing Record 25 of Set 5 | tailai
# Processing Record 26 of Set 5 | zhigansk
# Processing Record 27 of Set 5 | atuona
# Processing Record 28 of Set 5 | port alfred
# Processing Record 29 of Set 5 | kichera
# Processing Record 30 of Set 5 | kaeo
# Processing Record 31 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 5 | kavieng
# Processing Record 33 of Set 5 | fuxin
# Processing Record 34 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 5 | bibai
# Processing Record 36 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 37 of Set 5 | puerto ayora
# Processing Record 38 of Set 5 | kharp
# Processing Record 39 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 40 of Set 5 | lata
# Processing Record 41 of Set 5 | birjand
# Processing Record 42 of Set 5 | lebu
# Processing Record 43 of Set 5 | asau
# Processing Record 44 of Set 5 | yar-sale
# Processing Record 45 of Set 5 | hovd
# Processing Record 46 of Set 5 | leningradskiy
# Processing Record 47 of Set 5 | sorong
# Processing Record 48 of Set 5 | gold coast
# Processing Record 49 of Set 5 | pisco
# Processing Record 50 of Set 5 | sao joaquim
# Processing Record 1 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 6 | ometepec
# Processing Record 3 of Set 6 | kachug
# Processing Record 4 of Set 6 | port lincoln
# Processing Record 5 of Set 6 | muncar
# Processing Record 6 of Set 6 | abu dhabi
# Processing Record 7 of Set 6 | vladicin han
# Processing Record 8 of Set 6 | ivdel
# Processing Record 9 of Set 6 | rawlins
# Processing Record 10 of Set 6 | lavrentiya
# Processing Record 11 of Set 6 | ramhormoz
# Processing Record 12 of Set 6 | calvinia
# Processing Record 13 of Set 6 | guiratinga
# Processing Record 14 of Set 6 | roma
# Processing Record 15 of Set 6 | tasiilaq
# Processing Record 16 of Set 6 | hambantota
# Processing Record 17 of Set 6 | carnarvon
# Processing Record 18 of Set 6 | ketchikan
# Processing Record 19 of Set 6 | saint combs
# City not found. Skipping...
# Processing Record 20 of Set 6 | yola
# Processing Record 21 of Set 6 | katherine
# Processing Record 22 of Set 6 | caiaponia
# Processing Record 23 of Set 6 | upington
# Processing Record 24 of Set 6 | san pedro
# Processing Record 25 of Set 6 | thompson
# Processing Record 26 of Set 6 | urdoma
# Processing Record 27 of Set 6 | vao
# Processing Record 28 of Set 6 | port elizabeth
# Processing Record 29 of Set 6 | privolzhsk
# Processing Record 30 of Set 6 | faya
# Processing Record 31 of Set 6 | kamenka
# Processing Record 32 of Set 6 | ilhabela
# Processing Record 33 of Set 6 | prince rupert
# Processing Record 34 of Set 6 | broome
# Processing Record 35 of Set 6 | parrita
# Processing Record 36 of Set 6 | sangar
# Processing Record 37 of Set 6 | menongue
# Processing Record 38 of Set 6 | qurayyat
# Processing Record 39 of Set 6 | lewistown
# Processing Record 40 of Set 6 | iskateley
# Processing Record 41 of Set 6 | nanzhang
# Processing Record 42 of Set 6 | ancud
# Processing Record 43 of Set 6 | rawson
# Processing Record 44 of Set 6 | praia
# Processing Record 45 of Set 6 | souillac
# Processing Record 46 of Set 6 | galveston
# Processing Record 47 of Set 6 | wilmington
# Processing Record 48 of Set 6 | ostrovnoy
# Processing Record 49 of Set 6 | upernavik
# Processing Record 50 of Set 6 | katsiveli
# City not found. Skipping...
# Processing Record 1 of Set 7 | tiszadob
# Processing Record 2 of Set 7 | fernley
# Processing Record 3 of Set 7 | valleyview
# Processing Record 4 of Set 7 | aklavik
# Processing Record 5 of Set 7 | armidale
# Processing Record 6 of Set 7 | kamaishi
# Processing Record 7 of Set 7 | bayanday
# Processing Record 8 of Set 7 | gladstone
# Processing Record 9 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 10 of Set 7 | beringovskiy
# Processing Record 11 of Set 7 | mehamn
# Processing Record 12 of Set 7 | walvis bay
# Processing Record 13 of Set 7 | salalah
# Processing Record 14 of Set 7 | norman wells
# Processing Record 15 of Set 7 | tecoanapa
# Processing Record 16 of Set 7 | tual
# Processing Record 17 of Set 7 | nioro
# Processing Record 18 of Set 7 | aktau
# Processing Record 19 of Set 7 | santa cruz cabralia
# Processing Record 20 of Set 7 | sarangani
# Processing Record 21 of Set 7 | pevek
# Processing Record 22 of Set 7 | nauta
# Processing Record 23 of Set 7 | road town
# Processing Record 24 of Set 7 | tessalit
# Processing Record 25 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 7 | snezhnogorsk
# Processing Record 27 of Set 7 | adrar
# Processing Record 28 of Set 7 | terrasini
# Processing Record 29 of Set 7 | ostersund
# Processing Record 30 of Set 7 | rio gallegos
# Processing Record 31 of Set 7 | eydhafushi
# Processing Record 32 of Set 7 | tigil
# Processing Record 33 of Set 7 | oyamel
# City not found. Skipping...
# Processing Record 34 of Set 7 | djenne
# Processing Record 35 of Set 7 | aksum
# Processing Record 36 of Set 7 | macenta
# Processing Record 37 of Set 7 | shaunavon
# Processing Record 38 of Set 7 | polunochnoye
# Processing Record 39 of Set 7 | santiago de cao
# Processing Record 40 of Set 7 | dehloran
# Processing Record 41 of Set 7 | noyabrsk
# Processing Record 42 of Set 7 | fomboni
# Processing Record 43 of Set 7 | kenai
# Processing Record 44 of Set 7 | lagos
# Processing Record 45 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 46 of Set 7 | san roque
# Processing Record 47 of Set 7 | latung
# Processing Record 48 of Set 7 | ewa beach
# Processing Record 49 of Set 7 | berlevag
# Processing Record 50 of Set 7 | jiazi
# Processing Record 1 of Set 8 | ahipara
# Processing Record 2 of Set 8 | ippy
# Processing Record 3 of Set 8 | saint-francois
# Processing Record 4 of Set 8 | evensk
# Processing Record 5 of Set 8 | naranjito
# Processing Record 6 of Set 8 | taraza
# Processing Record 7 of Set 8 | shenjiamen
# Processing Record 8 of Set 8 | ko samui
# Processing Record 9 of Set 8 | hangu
# Processing Record 10 of Set 8 | ouango
# Processing Record 11 of Set 8 | gornopravdinsk
# Processing Record 12 of Set 8 | namibe
# Processing Record 13 of Set 8 | manggar
# Processing Record 14 of Set 8 | katrineholm
# Processing Record 15 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 8 | ormara
# Processing Record 17 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 18 of Set 8 | muzhi
# Processing Record 19 of Set 8 | iqaluit
# Processing Record 20 of Set 8 | tanout
# Processing Record 21 of Set 8 | dudinka
# Processing Record 22 of Set 8 | atambua
# Processing Record 23 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 24 of Set 8 | meulaboh
# Processing Record 25 of Set 8 | caravelas
# Processing Record 26 of Set 8 | saint-pierre
# Processing Record 27 of Set 8 | erenhot
# Processing Record 28 of Set 8 | roald
# Processing Record 29 of Set 8 | opuwo
# Processing Record 30 of Set 8 | riyadh
# Processing Record 31 of Set 8 | madang
# Processing Record 32 of Set 8 | manama
# Processing Record 33 of Set 8 | jieshou
# Processing Record 34 of Set 8 | kon tum
# Processing Record 35 of Set 8 | tanggu
# Processing Record 36 of Set 8 | mahadday weyne
# City not found. Skipping...
# Processing Record 37 of Set 8 | progreso
# Processing Record 38 of Set 8 | saldanha
# Processing Record 39 of Set 8 | alofi
# Processing Record 40 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 8 | omboue
# Processing Record 42 of Set 8 | lagoa
# Processing Record 43 of Set 8 | dosso
# Processing Record 44 of Set 8 | beyneu
# Processing Record 45 of Set 8 | bubaque
# Processing Record 46 of Set 8 | aldan
# Processing Record 47 of Set 8 | rumonge
# Processing Record 48 of Set 8 | eregli
# Processing Record 49 of Set 8 | tuatapere
# Processing Record 50 of Set 8 | flin flon
# Processing Record 1 of Set 9 | taft
# Processing Record 2 of Set 9 | oktyabrskiy
# Processing Record 3 of Set 9 | poum
# Processing Record 4 of Set 9 | makakilo city
# Processing Record 5 of Set 9 | anloga
# Processing Record 6 of Set 9 | bandarbeyla
# Processing Record 7 of Set 9 | nemuro
# Processing Record 8 of Set 9 | znamenskoye
# Processing Record 9 of Set 9 | baillif
# Processing Record 10 of Set 9 | general roca
# Processing Record 11 of Set 9 | muros
# Processing Record 12 of Set 9 | cururupu
# Processing Record 13 of Set 9 | nam tha
# City not found. Skipping...
# Processing Record 14 of Set 9 | santa barbara
# Processing Record 15 of Set 9 | kholm
# Processing Record 16 of Set 9 | sungairaya
# Processing Record 17 of Set 9 | tarakan
# Processing Record 18 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 19 of Set 9 | finote selam
# Processing Record 20 of Set 9 | sao geraldo do araguaia
# Processing Record 21 of Set 9 | constitucion
# Processing Record 22 of Set 9 | yerbogachen
# Processing Record 23 of Set 9 | mouzakion
# City not found. Skipping...
# Processing Record 24 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 9 | sobolevo
# Processing Record 26 of Set 9 | koroni
# Processing Record 27 of Set 9 | congonhas
# Processing Record 28 of Set 9 | papar
# Processing Record 29 of Set 9 | norilsk
# Processing Record 30 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 31 of Set 9 | beloha
# Processing Record 32 of Set 9 | kudahuvadhoo
# Processing Record 33 of Set 9 | cuamba
# Processing Record 34 of Set 9 | bani
# Processing Record 35 of Set 9 | zabinka
# City not found. Skipping...
# Processing Record 36 of Set 9 | arlit
# Processing Record 37 of Set 9 | ternate
# Processing Record 38 of Set 9 | the valley
# Processing Record 39 of Set 9 | gravdal
# Processing Record 40 of Set 9 | lasa
# Processing Record 41 of Set 9 | tautira
# Processing Record 42 of Set 9 | berbera
# Processing Record 43 of Set 9 | kendari
# Processing Record 44 of Set 9 | taonan
# Processing Record 45 of Set 9 | agadez
# Processing Record 46 of Set 9 | tunceli
# Processing Record 47 of Set 9 | tambul
# City not found. Skipping...
# Processing Record 48 of Set 9 | bayonet point
# Processing Record 49 of Set 9 | ballina
# Processing Record 50 of Set 9 | rocha
# Processing Record 1 of Set 10 | aksha
# Processing Record 2 of Set 10 | vostok
# Processing Record 3 of Set 10 | maniitsoq
# Processing Record 4 of Set 10 | acari
# Processing Record 5 of Set 10 | nuuk
# Processing Record 6 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 10 | rafai
# Processing Record 8 of Set 10 | camocim
# Processing Record 9 of Set 10 | sorland
# Processing Record 10 of Set 10 | el campo
# Processing Record 11 of Set 10 | itupiranga
# Processing Record 12 of Set 10 | barranca
# Processing Record 13 of Set 10 | acajutla
# Processing Record 14 of Set 10 | talara
# Processing Record 15 of Set 10 | sechura
# Processing Record 16 of Set 10 | bijie
# Processing Record 17 of Set 10 | coronel vivida
# Processing Record 18 of Set 10 | karabash
# Processing Record 19 of Set 10 | takoradi
# Processing Record 20 of Set 10 | ayer itam
# City not found. Skipping...
# Processing Record 21 of Set 10 | tahe
# Processing Record 22 of Set 10 | terrace
# Processing Record 23 of Set 10 | yenagoa
# Processing Record 24 of Set 10 | natal
# Processing Record 25 of Set 10 | borovskoy
# Processing Record 26 of Set 10 | egvekinot
# Processing Record 27 of Set 10 | marienburg
# Processing Record 28 of Set 10 | hammerfest
# Processing Record 29 of Set 10 | kununurra
# Processing Record 30 of Set 10 | guarapari
# Processing Record 31 of Set 10 | san patricio
# Processing Record 32 of Set 10 | ca mau
# Processing Record 33 of Set 10 | crib point
# Processing Record 34 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 35 of Set 10 | turukhansk
# Processing Record 36 of Set 10 | kavaratti
# Processing Record 37 of Set 10 | parfino
# Processing Record 38 of Set 10 | salinas
# Processing Record 39 of Set 10 | balimo
# City not found. Skipping...
# Processing Record 40 of Set 10 | waingapu
# Processing Record 41 of Set 10 | sanda
# Processing Record 42 of Set 10 | taksimo
# Processing Record 43 of Set 10 | awjilah
# Processing Record 44 of Set 10 | kondol
# Processing Record 45 of Set 10 | hong gai
# Processing Record 46 of Set 10 | ambunti
# Processing Record 47 of Set 10 | santa fe
# Processing Record 48 of Set 10 | geraldton
# Processing Record 49 of Set 10 | anglet
# Processing Record 50 of Set 10 | chapais
# Processing Record 1 of Set 11 | nago
# Processing Record 2 of Set 11 | paita
# Processing Record 3 of Set 11 | kyrksaeterora
# Processing Record 4 of Set 11 | la teste-de-buch
# Processing Record 5 of Set 11 | severo-kurilsk
# Processing Record 6 of Set 11 | yinchuan
# Processing Record 7 of Set 11 | dwarka
# Processing Record 8 of Set 11 | atessa
# Processing Record 9 of Set 11 | mchinji
# Processing Record 10 of Set 11 | port hedland
# Processing Record 11 of Set 11 | la orilla
# Processing Record 12 of Set 11 | nova esperanca
# Processing Record 13 of Set 11 | villa maria
# Processing Record 14 of Set 11 | lompoc
# Processing Record 15 of Set 11 | gat
# Processing Record 16 of Set 11 | biak
# Processing Record 17 of Set 11 | san clemente
# Processing Record 18 of Set 11 | zhangye
# Processing Record 19 of Set 11 | koslan
# Processing Record 20 of Set 11 | aripuana
# Processing Record 21 of Set 11 | pak phanang
# Processing Record 22 of Set 11 | korla
# Processing Record 23 of Set 11 | coolum beach
# Processing Record 24 of Set 11 | miracema do tocantins
# Processing Record 25 of Set 11 | shimoda
# Processing Record 26 of Set 11 | nurota
# Processing Record 27 of Set 11 | udachnyy
# Processing Record 28 of Set 11 | viedma
# Processing Record 29 of Set 11 | mamallapuram
# Processing Record 30 of Set 11 | sao gabriel da cachoeira
# Processing Record 31 of Set 11 | la ronge
# Processing Record 32 of Set 11 | caucaia
# Processing Record 33 of Set 11 | novyy urgal
# Processing Record 34 of Set 11 | karratha
# Processing Record 35 of Set 11 | salinopolis
# Processing Record 36 of Set 11 | colac
# Processing Record 37 of Set 11 | mount isa
# Processing Record 38 of Set 11 | altamira
# Processing Record 39 of Set 11 | iwanai
# Processing Record 40 of Set 11 | ishigaki
# Processing Record 41 of Set 11 | burica
# City not found. Skipping...
# Processing Record 42 of Set 11 | banda aceh
# Processing Record 43 of Set 11 | verkh-usugli
# Processing Record 44 of Set 11 | harper
# Processing Record 45 of Set 11 | valpoi
# Processing Record 46 of Set 11 | canalete
# Processing Record 47 of Set 11 | nelson bay
# Processing Record 48 of Set 11 | wajid
# Processing Record 49 of Set 11 | fare
# Processing Record 50 of Set 11 | vegueta
# Processing Record 1 of Set 12 | saint-joseph
# Processing Record 2 of Set 12 | camana
# Processing Record 3 of Set 12 | vila velha
# Processing Record 4 of Set 12 | atbasar
# Processing Record 5 of Set 12 | yuza
# Processing Record 6 of Set 12 | necochea
# Processing Record 7 of Set 12 | soma
# Processing Record 8 of Set 12 | dickinson
# Processing Record 9 of Set 12 | pryluky
# Processing Record 10 of Set 12 | arkhangelsk
# Processing Record 11 of Set 12 | denpasar
# Processing Record 12 of Set 12 | emba
# Processing Record 13 of Set 12 | kastamonu
# Processing Record 14 of Set 12 | portland
# Processing Record 15 of Set 12 | buta
# Processing Record 16 of Set 12 | pulawy
# Processing Record 17 of Set 12 | aykhal
# Processing Record 18 of Set 12 | aasiaat
# Processing Record 19 of Set 12 | christchurch
# Processing Record 20 of Set 12 | hayden
# Processing Record 21 of Set 12 | gambela
# Processing Record 22 of Set 12 | kotdwara
# Processing Record 23 of Set 12 | nassogne
# Processing Record 24 of Set 12 | derzhavinsk
# Processing Record 25 of Set 12 | rancho palos verdes
# Processing Record 26 of Set 12 | sturgeon falls
# Processing Record 27 of Set 12 | seoul
# Processing Record 28 of Set 12 | griffith
# Processing Record 29 of Set 12 | kosino
# Processing Record 30 of Set 12 | xiongzhou
# Processing Record 31 of Set 12 | vanimo
# Processing Record 32 of Set 12 | antalaha
# Processing Record 33 of Set 12 | vestmannaeyjar
# Processing Record 34 of Set 12 | slave lake
# Processing Record 35 of Set 12 | wanning
# Processing Record 36 of Set 12 | dhidhdhoo
# Processing Record 37 of Set 12 | borlange
# City not found. Skipping...
# Processing Record 38 of Set 12 | angra
# City not found. Skipping...
# Processing Record 39 of Set 12 | placido de castro
# Processing Record 40 of Set 12 | sakakah
# Processing Record 41 of Set 12 | novoagansk
# Processing Record 42 of Set 12 | presidencia roque saenz pena
# Processing Record 43 of Set 12 | horta
# Processing Record 44 of Set 12 | kahului
# Processing Record 45 of Set 12 | assentoft
# Processing Record 46 of Set 12 | kaffrine
# Processing Record 47 of Set 12 | campbell river
# Processing Record 48 of Set 12 | coos bay
# Processing Record 49 of Set 12 | deputatskiy
# Processing Record 50 of Set 12 | baherden
# Processing Record 1 of Set 13 | ulaangom
# Processing Record 2 of Set 13 | kaeng khlo
# City not found. Skipping...
# Processing Record 3 of Set 13 | dothan
# Processing Record 4 of Set 13 | san juan
# Processing Record 5 of Set 13 | dukat
# Processing Record 6 of Set 13 | logan lake
# Processing Record 7 of Set 13 | north platte
# Processing Record 8 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 9 of Set 13 | boshan
# Processing Record 10 of Set 13 | morondava
# Processing Record 11 of Set 13 | nuevo progreso
# Processing Record 12 of Set 13 | keti bandar
# Processing Record 13 of Set 13 | lokomotivnyy
# Processing Record 14 of Set 13 | ulladulla
# Processing Record 15 of Set 13 | hearst
# Processing Record 16 of Set 13 | hami
# Processing Record 17 of Set 13 | japura
# Processing Record 18 of Set 13 | nome
# Processing Record 19 of Set 13 | vila do maio
# Processing Record 20 of Set 13 | sao joao da barra
# Processing Record 21 of Set 13 | chaumont
# Processing Record 22 of Set 13 | padang
# Processing Record 23 of Set 13 | novo aripuana
# Processing Record 24 of Set 13 | nabire
# Processing Record 25 of Set 13 | hamilton
# Processing Record 26 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 27 of Set 13 | tabuk
# Processing Record 28 of Set 13 | itoman
# Processing Record 29 of Set 13 | aswan
# Processing Record 30 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 31 of Set 13 | sept-iles
# Processing Record 32 of Set 13 | lichinga
# Processing Record 33 of Set 13 | fairbanks
# Processing Record 34 of Set 13 | zumarraga
# Processing Record 35 of Set 13 | carazinho
# Processing Record 36 of Set 13 | west monroe
# Processing Record 37 of Set 13 | fujin
# Processing Record 38 of Set 13 | ulaanbaatar
# Processing Record 39 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 40 of Set 13 | litoral del san juan
# City not found. Skipping...
# Processing Record 41 of Set 13 | karsava
# Processing Record 42 of Set 13 | bowen
# Processing Record 43 of Set 13 | the pas
# Processing Record 44 of Set 13 | cap-aux-meules
# Processing Record 45 of Set 13 | queimadas
# Processing Record 46 of Set 13 | matara
# Processing Record 47 of Set 13 | hwange
# Processing Record 48 of Set 13 | ekhabi
# Processing Record 49 of Set 13 | pascagoula
# Processing Record 50 of Set 13 | sur
# Processing Record 1 of Set 14 | marsa matruh
# Processing Record 2 of Set 14 | port-gentil
# Processing Record 3 of Set 14 | picton
# Processing Record 4 of Set 14 | hun
# Processing Record 5 of Set 14 | chicama
# Processing Record 6 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 7 of Set 14 | maragheh
# Processing Record 8 of Set 14 | ottumwa
# Processing Record 9 of Set 14 | morant bay
# Processing Record 10 of Set 14 | koratla
# Processing Record 11 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 12 of Set 14 | nha trang
# Processing Record 13 of Set 14 | bouna
# Processing Record 14 of Set 14 | cockburn town
# Processing Record 15 of Set 14 | kristianstad
# Processing Record 16 of Set 14 | otofuke
# Processing Record 17 of Set 14 | ocampo
# Processing Record 18 of Set 14 | jiuquan
# Processing Record 19 of Set 14 | oranjestad
# Processing Record 20 of Set 14 | alto araguaia
# Processing Record 21 of Set 14 | catamarca
# Processing Record 22 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 23 of Set 14 | shirokiy
# Processing Record 24 of Set 14 | zhezkazgan
# Processing Record 25 of Set 14 | hualmay
# Processing Record 26 of Set 14 | puerto escondido
# Processing Record 27 of Set 14 | cayenne
# Processing Record 28 of Set 14 | dondo
# Processing Record 29 of Set 14 | abrau-dyurso
# Processing Record 30 of Set 14 | madoc
# Processing Record 31 of Set 14 | soria
# Processing Record 32 of Set 14 | jijiga
# Processing Record 33 of Set 14 | kirkcudbright
# Processing Record 34 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 14 | fuerte olimpo
# Processing Record 36 of Set 14 | akdepe
# Processing Record 37 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 38 of Set 14 | palmer
# Processing Record 39 of Set 14 | solnechnyy
# Processing Record 40 of Set 14 | male
# Processing Record 41 of Set 14 | pastavy
# Processing Record 42 of Set 14 | sambava
# Processing Record 43 of Set 14 | bloemhof
# Processing Record 44 of Set 14 | chimbote
# Processing Record 45 of Set 14 | nyurba
# Processing Record 46 of Set 14 | jumla
# Processing Record 47 of Set 14 | formosa
# Processing Record 48 of Set 14 | akwatia
# Processing Record 49 of Set 14 | yining
# Processing Record 50 of Set 14 | ndola
# Processing Record 1 of Set 15 | haines junction
# Processing Record 2 of Set 15 | mana
# Processing Record 3 of Set 15 | honiara
# Processing Record 4 of Set 15 | grand-santi
# Processing Record 5 of Set 15 | aksarka
# Processing Record 6 of Set 15 | muroto
# Processing Record 7 of Set 15 | saint anthony
# Processing Record 8 of Set 15 | waterfoot
# Processing Record 9 of Set 15 | luba
# Processing Record 10 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 11 of Set 15 | arroyo
# Processing Record 12 of Set 15 | ust-kuyga
# Processing Record 13 of Set 15 | talin
# Processing Record 14 of Set 15 | morgan city
# Processing Record 15 of Set 15 | newport
# Processing Record 16 of Set 15 | mahanoro
# Processing Record 17 of Set 15 | yichun
# Processing Record 18 of Set 15 | moron
# Processing Record 19 of Set 15 | grand gaube
# Processing Record 20 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 15 | bontang
# Processing Record 22 of Set 15 | elmina
# Processing Record 23 of Set 15 | havoysund
# Processing Record 24 of Set 15 | rudbar
# Processing Record 25 of Set 15 | gazli
# Processing Record 26 of Set 15 | ankaran
# Processing Record 27 of Set 15 | skagastrond
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 665

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
weather_database_df = pd.DataFrame(city_data)

# Order the columns 
weather_database_df = weather_database_df[["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]

# Print head of dataset
weather_database_df.head(10)
# Out:
#            City Country                 Date    Lat     Lng  Max Temp  \
# 0  Gornozavodsk      RU  2020-08-23 17:20:24  58.38   58.32     49.48
# 1      Havelock      US  2020-08-23 17:18:39  34.88  -76.90     86.00
# 2        Kodiak      US  2020-08-23 17:19:34  57.79 -152.41     55.40
# 3        Najran      SA  2020-08-23 17:20:05  17.49   44.13     96.80
# 4      Acapulco      MX  2020-08-23 17:17:16  16.86  -99.89     82.40
# 5         Arman      RU  2020-08-23 17:20:25  59.70  150.17     40.37
# 6           Eyl      SO  2020-08-23 17:20:25   7.98   49.82     77.79
# 7       Ushuaia      AR  2020-08-23 17:19:12 -54.80  -68.30     35.60
# 8       Mataura      NZ  2020-08-23 17:19:32 -46.19  168.86     44.01
# 9        Dikson      RU  2020-08-23 17:19:23  73.51   80.55     46.54
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        93          17        3.22          few clouds
# 1        62          20        6.93          few clouds
# 2        87          90        3.36     overcast clouds
# 3        16         100        6.93     overcast clouds
# 4        83          75        3.36       broken clouds
# 5        70           0       10.04           clear sky
# 6        70          54       28.74       broken clouds
# 7        74          40       11.41    scattered clouds
# 8        91          46        3.00    scattered clouds
# 9        78           0        9.64           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
weather_database_df.to_csv(output_data_file, index_label="City_ID")
